# %%
# Load libraries
import pandas as pd
import numpy as np
import matplotlib

# Directly displays plotly plots in notebook
import plotly
import plotly.io as pio                           
pio.renderers.default = "notebook_connected"

# Alluvial diagram
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.colors as mcolors

# %%
# Alluvial diagram (Sankey workaround)
# Needs columns: (Ambiguous Cluster Name, Disambiguous Cluster Name), (Ambiguous Question, Disambiguous Question), Weight (column of 1's)

'''
CHANGE .CSV NAME BELOW TO LOAD DATA
'''
df = pd.read_csv("20AnimalsDataset_FinalWithNames.csv")

# Step 1: Create node lists and mapping
left = df["Ambiguous Cluster Name"].unique().tolist()       
right = df["Disambiguous Cluster Name"].unique().tolist()    
labels = left + right                                              
idx = {lab: i for i, lab in enumerate(labels)}                     

# Step 2: Assign colors to left nodes
palette = px.colors.qualitative.Pastel
node_colors = {lab: palette[i % len(palette)] for i, lab in enumerate(left)}  

# Step 3: Assign link colors based on source node's color
link_colors = df["Ambiguous Cluster Name"].map(node_colors)             

### Make colors transparent
alpha = 0.5  
link_colors_transparent = [c.replace("rgb", "rgba").replace(")", f", {alpha})") for c in link_colors]

# Step 4: Convert names to node indices for links
sources = df["Ambiguous Cluster Name"].map(idx)              
targets = df["Disambiguous Cluster Name"].map(idx)              

# Step 5: Create custom data for tooltip, with Ambiguous Question (Column 1) and Disambiguous Question (Column 2)
custom = np.stack([df["Ambiguous Question"], df["Disambiguous Question"]], axis=1)

# Step 6: Create custom tooltip for each node
### Compute incoming/outgoing sums of links entering/leaving node
out_by_left  = df.groupby("Ambiguous Cluster Name")["Weight"].sum()
in_by_right  = df.groupby("Disambiguous Cluster Name")["Weight"].sum()

### Build a hovertemplate string for each node (same order as `labels`)
node_text = []
for lab in labels:
    if lab in left:
        node_text.append(f"<b>{lab}</b><br>Outgoing flow count: {float(out_by_left.get(lab, 0))}")
    else:
        node_text.append(f"<b>{lab}</b><br>Incoming flow count: {float(in_by_right.get(lab, 0))}")

# Step 7: Build alluvial diagram
fig = go.Figure(go.Sankey(
    arrangement="snap",
    node=dict(                                                      
        label=labels,
        pad=10,
        thickness=30,                                              
        color=[node_colors.get(lab, "#cccccc") for lab in labels],
        customdata=node_text,  
        hovertemplate="%{customdata}<extra></extra>"              
    ),
    link=dict(
        source=sources,                                             
        target=targets,                                            
        value=df["Weight"],                                   
        customdata=custom,
        color=link_colors_transparent,                             
        hovertemplate=(
            "<b>%{source.label}</b> → <b>%{target.label}</b><br>"
            "Ambiguous: %{customdata[0]}<br>"
            "Disambiguated: %{customdata[1]}<br>"
            "<extra></extra>"
        )
    )
))

# Add title to figure
fig.update_layout(
    title_text="Alluvial Diagram of Ambiguous → Disambiguated Cluster Topics"
)

fig.show()

# Export to .html
# fig.write_html("alluvial_diagram.html", include_plotlyjs="cdn")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="bced7af9-1ce3-41da-bb2d-e2b0c81812f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bced7af9-1ce3-41da-bb2d-e2b0c81812f2")) {                    Plotly.newPlot(                        "bced7af9-1ce3-41da-bb2d-e2b0c81812f2",                        [{"arrangement":"snap","link":{"color":["rgba(102, 197, 204, 0.5)","rgba(246, 207, 113, 0.5)","rgba(248, 156, 116, 0.5)","rgba(248, 156, 116, 0.5)","rgba(248, 156, 116, 0.5)","rgba(102, 197, 204, 0.5)","rgba(220, 176, 242, 0.5)","rgba(246, 207, 113, 0.5)","rgba(246, 207, 113, 0.5)","rgba(220, 176, 242, 0.5)","rgba(102, 197, 204, 0.5)","rgba(246, 207, 113, 0.5)","rgba(246, 207, 113, 0.5)","rgba(102, 197, 204, 0.5)","rgba(102, 197, 204, 0.5)","rgba(246, 207, 113, 0.5)","rgba(102, 197, 204, 0.5)","rgba(220, 176, 242, 0.5)","rgba(248, 156, 116, 0.5)","rgba(220, 176, 242, 0.5)"],"customdata":[["Are they more vocal when they're hungry or excited?","Are dogs more vocal when dogs are hungry or excited?"],["How sensitive are they to environmental changes?","How sensitive are dogs to environmental changes?"],["What kind of enrichment helps them feel more secure?","What kind of enrichment helps dogs feel more secure?"],["How do they show signs of trust toward their caregivers?","How do dogs show signs of trust toward their caregivers?"],["What do they typically do when they feel threatened?","What do dogs typically do when dogs feel threatened?"],["Are sudden noises always startling to them?","Are sudden noises always startling to cats?"],["Why do they sometimes follow people around?","Why do cats sometimes follow people around?"],["Why might they pace in new environments?","Why might cats pace in new environments?"],["Is pacing a sign of anticipation or anxiety?","Is the pacing of cats a sign of anticipation or anxiety?"],["Do they show preference for certain people over others?","Do cats show preference for certain people over others?"],["What might cause them to vocalize more at night?","What might cause monkeys to vocalize more at night?"],["Why might they isolate themselves at times?","Why might monkeys isolate themselves at times?"],["Why do they often repeat that behavior in the mornings?","Why do monkeys often repeat that behavior in the mornings?"],["Are they expressing contentment when they stretch like that?","Are monkeys expressing contentment when monkeys stretch like that?"],["Can their posture indicate interest or boredom?","Can the posture of monkeys indicate interest or boredom?"],["Why do they retreat when approached suddenly?","Why do horses retreat when approached suddenly?"],["Do they rely on routine to feel stable?","Do horses rely on routine to feel stable?"],["Are they influenced by others in their group?","Are horses influenced by other horses in their group?"],["Do they bond more easily with certain species?","Do horses bond more easily with certain species?"],["Are they more active when alone or in groups?","Are horses more active when alone or in groups?"]],"hovertemplate":"\u003cb\u003e%{source.label}\u003c\u002fb\u003e \u2192 \u003cb\u003e%{target.label}\u003c\u002fb\u003e\u003cbr\u003eAmbiguous: %{customdata[0]}\u003cbr\u003eDisambiguated: %{customdata[1]}\u003cbr\u003e\u003cextra\u003e\u003c\u002fextra\u003e","source":{"dtype":"i1","bdata":"AAECAgIAAwEBAwABAQAAAQADAgM="},"target":{"dtype":"i1","bdata":"BAQEBAQFBQUFBQYGBgYGBwcHBwc="},"value":{"dtype":"i1","bdata":"AQEBAQEBAQEBAQEBAQEBAQEBAQE="}},"node":{"color":["rgb(102, 197, 204)","rgb(246, 207, 113)","rgb(248, 156, 116)","rgb(220, 176, 242)","#cccccc","#cccccc","#cccccc","#cccccc"],"customdata":["\u003cb\u003eCauses of behavior\u003c\u002fb ...
